# %% [markdown]
# ---
# toc: False
# layout: tailwindPost
# infoGraph: interviewFinal
# title: LinkedIn/Interview Prep Final
# description: A collection and review of my achievements and learnings as an AP CSA student
# courses: { csa: {week: 36} }
# type: ccc
# categories: [Final]
# permalink: /finalinterview/
# sticky_rank: 1
# ---

# %% [markdown]
# ## Projects Overview & Team Collaboration
#
# - **Fortune Finders**
#   *Role: Scrum Master and Integrator*
#   2D interactive game introducing financial literacy concepts such as banking, cryptocurrency, and stock market dynamics.
#   - Players can earn and lose balance by playing various games
# ![Image](https://github.com/user-attachments/assets/5931a52d-9fbe-4c17-a37e-507b32d2f03d)
# ---
#
# ## Teamwork Methodologies & Artifacts
#
# - Created KanBan board to streamline planning and communication into one area.
# ![Image](https://github.com/user-attachments/assets/533a8b0f-049e-4fa4-8e3a-a0e11b5d8d9f)
# - Countless planning issues, following Agile Development sprints
# ![Image](https://github.com/user-attachments/assets/e629e504-3987-4a3f-9504-be93ce9555ee)
# - Utilized tools like draw.io to illustrate game flow and FIgma/Figjam to create UML Diagrams and organize ideas
# ![Image](https://github.com/user-attachments/assets/0aaf8b41-21c6-42f5-87e4-31d1da076805)
# ![Image](https://github.com/user-attachments/assets/1fac812c-fad7-447c-98ff-7b208d4f1f4c)
#
# ---
#
# ## Full Stack Skill Set
#
# | Layer         | Tech Stack                                                                 |
# |---------------|----------------------------------------------------------------------------|
# | Frontend      | HTML, JavaScript, React                                     |
# | Backend       | Java, Spring Boot, Python (Flask)                                          |
# | Database      | SQLite, MySQL                                                              |
# | Tools         | Git, GitHub, Postman, Figma/FigJam, Docker, AWS, nginx, VSCode                                |
#
# ---
#
# ## Intro to ML Experience
#
# - **Tablesaw, Weka, Smile**
#     On top of utilizing pandas and scikit-learn to perform machine learning on the Titanic dataset, explored usage of Java ML through tools like Tablesaw, Weka, and Smile. After the team teach, created an organized and combined teaching file of all team teaches to make learning Java ML easier for future students
# ![Image](https://github.com/user-attachments/assets/34b63b50-f895-4a42-9163-08f51b654771)
#
# ---
#
# ## GitHub Highlights
#
# - [github.com](hhttps://github.com/AidanLau10)
#   - **Fortune Finders**: [Full project source with issues, pull requests, and commits showing my contributions.](https://github.com/CSA-Coders-2025/fintech)
#
# ---
#
# ## Showcasing Projects
#
# ### N@TM
# > 1st Iteration
# - Led a live demo for CS teacher and student leaders.
# - Highlighted our UI/UX flow and backend grading automation.
# "Looks great, amazing game. Would like to see more NPCs."
# - Brett Pollak
#
# "I learned that the github figure is an octopus and not a cat, Life changing event. :)
# Good animation, good topics for the questions. Looking forward to see the ChatGPT grading!"
# - Ms. Pataki
# <p align="center">
#   <img src="https://github.com/user-attachments/assets/ef5cb111-dbf3-49e1-af66-4c43f6c15917" width="200"/>
#   <img src="https://github.com/user-attachments/assets/03c668c4-1e94-437d-932a-7c71251c0105" width="200"/>
#   <img src="https://github.com/user-attachments/assets/6c0bebea-3a79-4ea4-acf9-220c4ab663fe" width="200"/>
# </p>
# <p align="center">
#   <img src="https://github.com/user-attachments/assets/54a0cf0f-f405-4f29-bedc-ad9c470e4233" width="200"/>
#   <img src="https://github.com/user-attachments/assets/93cf0941-1b7e-4e75-a5ef-a4e20faaf28a" width="200"/>
#   <img src="https://github.com/user-attachments/assets/7c4ecd7e-19f1-47ff-82b9-9211c288964b" width="200"/>
# </p>
#
# ### HP CTE Expo
# > 2nd Iteration
# - Showcased Fortune Finders at HP CTE Expo.
# - Fulfilling to show our latest version to other high school students and professionals
#
# <p align="center">
#   <img src="https://github.com/user-attachments/assets/6289db89-51e9-401a-b087-5e81082754a0" width="200"/>
#   <img src="https://github.com/user-attachments/assets/25114f37-cba5-4cc4-8a3d-1abdab1c086a" width="200"/>
# </p>

# %% [markdown]
# <!-- Infographic - this depends on page.infoGraph frontmatter being set -->
# {%- include tailwind/infograph.html -%}
