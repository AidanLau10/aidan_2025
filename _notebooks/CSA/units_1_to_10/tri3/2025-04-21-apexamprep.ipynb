# %% [markdown]
# ---
# toc: False
# layout: tailwindPost
# infoGraph: apPrep
# title: AP Exam Prep
# description: My personal study guide for the AP CSA Exam
# courses: { csa: {week: 10} }
# type: ccc
# categories: [DevOps]
# permalink: /apprep/
# sticky_rank: 1
# ---

# %% [markdown]
# <!-- Infographic - this depends on page.infoGraph frontmatter being set -->
# {%- include tailwind/infograph.html -%}
