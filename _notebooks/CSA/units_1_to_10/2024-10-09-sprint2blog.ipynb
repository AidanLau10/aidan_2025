// %% [markdown]
// ---
// layout: post
// toc: true
// title: Putting It All Together
// description: Combining all the units into one example
// categories: [AP CSA]
// courses: { csa: {week: 6} }
// type: ccc
// permalink: /puttingitalltogether
// ---

// %% [raw]
// <head>
//     <style>
//         body {
//         font-family: Arial, sans-serif;
//     }
//
//     .wardrobe {
//         position: relative;
//         width: 100%;
//         max-width: 900px;
//         margin: 0 auto;
//     }
//
//     .wardrobe-bg {
//         width: 100%;
//         height: auto;
//     }
//
//     .outfit {
//         position: absolute;
//         width: 100px;
//         height: 150px;
//         cursor: pointer;
//     }
//
//     /* Adjust clothes to be more centered and shift them up */
//     .black-hoodie {
//         top: 80px;  /* Shifted up from 100px */
//         left: 25%;
//     }
//
//     .black-pants {
//         top: 80px;  /* Shifted up from 100px */
//         left: 45%;
//     }
//
//     .black-shoes {
//         top: 80px;  /* Shifted up from 100px */
//         left: 65%;
//     }
//
//     .black-shorts {
//         top: 280px;  /* Shifted up from 300px */
//         left: 25%;
//     }
//
//     .black-sweater {
//         top: 280px;  /* Shifted up from 300px */
//         left: 45%;
//     }
//
//     .blue-collar {
//         top: 280px;  /* Shifted up from 300px */
//         left: 65%;
//     }
//
//     .blue-pants {
//         top: 480px;  /* Shifted up from 500px */
//         left: 25%;
//     }
//
//     .blue-quarterzip {
//         top: 480px;  /* Shifted up from 500px */
//         left: 45%;
//     }
//
//     .blue-shorts {
//         top: 480px;  /* Shifted up from 500px */
//         left: 65%;
//     }
//
//     /* Popup styles */
//     .popup {
//         display: none;
//         position: fixed;
//         top: 0;
//         left: 0;
//         width: 100%;
//         height: 100%;
//         background-color: rgba(0, 0, 0, 0.5);
//         z-index: 1;
//     }
//
//     .popup-content {
//         background-color: white;
//         color: black;
//         margin: 15% auto;
//         padding: 20px;
//         width: 60%;
//         border-radius: 10px;
//         text-align: center;
//         font-size: 18px;
//     }
//
//     .close {
//         float: right;
//         font-size: 28px;
//         cursor: pointer;
//         color: black;
//     }
//
//     </style>
// </head>
// <body>
//     <div class="wardrobe">
//         <img src="{{site.baseurl}}/images/outfits/wardrobe.jpg" class="wardrobe-bg" alt="Wardrobe Background">
//         <!-- Clothes on the wardrobe shelves -->
//         <img src="{{site.baseurl}}/images/outfits/blackhoodie.jpeg" alt="Black Hoodie" class="outfit black-hoodie" onclick="showPopup('Primitive and Reference Types')">
//         <img src="{{site.baseurl}}/images/outfits/blackpants.jpeg" alt="Black Pants" class="outfit black-pants" onclick="showPopup('Using Objects')">
//         <img src="{{site.baseurl}}/images/outfits/blackshoes.jpeg" alt="Black Shoes" class="outfit black-shoes" onclick="showPopup('Boolean Expressions and If Statements')">
//         <img src="{{site.baseurl}}/images/outfits/blackshorts.jpeg" alt="Black Shorts" class="outfit black-shorts" onclick="showPopup('Iteration')">
//         <img src="{{site.baseurl}}/images/outfits/blacksweater.jpeg" alt="Black Sweater" class="outfit black-sweater" onclick="showPopup('Writing Classes')">
//         <img src="{{site.baseurl}}/images/outfits/bluecollar.jpeg" alt="Blue Collar" class="outfit blue-collar" onclick="showPopup('Arrays')">
//         <img src="{{site.baseurl}}/images/outfits/bluepants.jpeg" alt="Blue Pants" class="outfit blue-pants" onclick="showPopup('ArrayLists')">
//         <img src="{{site.baseurl}}/images/outfits/bluequarterzip.jpeg" alt="Blue Quarter Zip" class="outfit blue-quarterzip" onclick="showPopup('2D Arrays')">
//         <img src="{{site.baseurl}}/images/outfits/blueshorts.jpeg" alt="Blue Shorts" class="outfit blue-shorts" onclick="showPopup('Inheritance')">
//     </div>
//
//     <!-- Popup -->
//     <div id="popup" class="popup">
//         <div class="popup-content">
//             <span class="close" onclick="hidePopup()">&times;</span>
//             <h2 id="java-topic-title"></h2>
//             <p id="java-topic-content"></p>
//         </div>
//     </div>
//
//     <script>
//         const javaTopics = {
//             'Primitive and Reference Types': 'Java supports primitive types (int, float, boolean, etc.) and reference types (objects like Strings and Arrays). Understanding the difference is crucial.',
//             'Using Objects': 'Objects in Java are instances of classes, and they allow us to model real-world entities in our programs.',
//             'Boolean Expressions and If Statements': 'Boolean expressions return true or false. They are used in control structures like if statements to control the flow of execution.',
//             'Iteration': 'Iteration in Java can be achieved through loops like for, while, and do-while to repeat a block of code.',
//             'Writing Classes': 'Classes define objects and their behavior. Writing classes involves declaring fields, constructors, and methods.',
//             'Arrays': 'Arrays are fixed-size data structures that hold multiple elements of the same type.',
//             'ArrayLists': 'ArrayLists are resizable arrays in Java that allow dynamic addition and removal of elements.',
//             '2D Arrays': '2D Arrays in Java represent a table-like structure, allowing us to work with rows and columns.',
//             'Inheritance': 'Inheritance allows one class to inherit fields and methods from another, promoting code reuse and a hierarchical class structure.'
//         };
//
//         function showPopup(topic) {
//             document.getElementById('java-topic-title').innerText = topic;
//             document.getElementById('java-topic-content').innerText = javaTopics[topic];
//             document.getElementById('popup').style.display = 'block';
//         }
//
//         function hidePopup() {
//             document.getElementById('popup').style.display = 'none';
//         }
//     </script>
// </body>
