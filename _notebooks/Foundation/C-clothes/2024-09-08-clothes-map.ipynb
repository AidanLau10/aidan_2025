# %% [raw]
# ---
# layout: post
# title: Map
#
# type: ccc
# comments: True
# permalink: /clothes/map
# menu: nav/clothes.html
# ---

# %% [raw]
# <head>
#     <link rel="stylesheet" href="https://unpkg.com/leaflet/dist/leaflet.css" />
#     <style>
#         /* Map container */
#         #map {
#             height: 500px;
#         }
#
#         /* Basic modal styling */
#         .modal {
#             display: none;
#             position: fixed;
#             z-index: 9999;
#             padding-top: 100px;
#             left: 0;
#             top: 0;
#             width: 100%;
#             height: 100%;
#             overflow-y: auto;
#             background-color: rgba(0, 0, 0, 0.7);
#         }
#
#         .modal-content {
#             background-color: #fefefe;
#             margin: auto;
#             padding: 20px;
#             border: 1px solid #888;
#             width: 80%;
#             max-width: 800px;
#             text-align: center;
#             color: #000; /* Set text color to black */
#         }
#
#         .modal img {
#             width: 100%;
#             height: auto;
#             margin-bottom: 20px;
#         }
#
#         /* Close button for the modal */
#         .close {
#             color: #aaa;
#             float: right;
#             font-size: 28px;
#             font-weight: bold;
#         }
#
#         .close:hover,
#         .close:focus {
#             color: black;
#             text-decoration: none;
#             cursor: pointer;
#         }
#
#         /* Prevent background scroll when modal is open */
#         body.modal-open {
#             overflow: hidden;
#         }
#
#         /* Custom style for Leaflet pop-ups */
#         .custom-popup {
#             color: #0000FF; /* Change this to the desired color for pop-up text */
#         }
#     </style>
# </head>
# <body>
#     <div id="map"></div>
#
#     <!-- Modal Structure -->
#     <div id="infoModal" class="modal">
#         <div class="modal-content">
#             <span class="close">&times;</span>
#             <div id="modalBody">
#                 <!-- Dynamic content will be injected here -->
#             </div>
#         </div>
#     </div>
#
#     <script src="https://unpkg.com/leaflet/dist/leaflet.js"></script>
#     <script>
#         // Initialize the map
#         var map = L.map('map').setView([20, 0], 2);
#
#         // Add a tile layer (Map provider)
#         L.tileLayer('https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
#             attribution: '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors'
#         }).addTo(map);
#
#         // Function to create content for pop-ups with a custom class
#         function getPopupContent(country) {
#             return `
#                 <div class="custom-popup">
#                     <h3>${country}</h3>
#                     <p style="color: #000">Brief info about ${country}'s clothing style.</p>
#                     <button onclick="openModal('${country}')">View Here</button>
#                 </div>
#             `;
#         }
#
#         // Add markers to the map
#         var usaMarker = L.marker([37.0902, -95.7129]).addTo(map);
#         usaMarker.bindPopup(getPopupContent('USA'));
#
#         var japanMarker = L.marker([36.2048, 138.2529]).addTo(map);
#         japanMarker.bindPopup(getPopupContent('Japan'));
#
#         var chinaMarker = L.marker([35.8617, 104.1954]).addTo(map);
#         chinaMarker.bindPopup(getPopupContent('China'));
#
#         // Modal logic
#         var modal = document.getElementById("infoModal");
#         var modalContent = document.getElementById("modalBody");
#         var closeModalButton = document.getElementsByClassName("close")[0];
#
#         // Close modal when "x" is clicked
#         closeModalButton.onclick = function() {
#             modal.style.display = "none";
#             document.body.classList.remove('modal-open');
#         }
#
#         // Close modal when clicking outside of the modal
#         window.onclick = function(event) {
#             if (event.target == modal) {
#                 modal.style.display = "none";
#                 document.body.classList.remove('modal-open');
#             }
#         }
#
#         // Function to open the modal with more information
#         function openModal(country) {
#             let modalHTML = '';
#             switch (country) {
#                 case 'USA':
#                     modalHTML = `
#                         <h2>More about USA's Clothing Style</h2>
#                         <h3>Cultural Influence on Clothing</h3>
#                         <p style="color: #000">The clothing style in the USA has been shaped by its diverse population, industrialization, and global influence. In the 19th century, the Industrial Revolution introduced mass production, which made clothing more accessible. American fashion developed unique characteristics influenced by the blend of immigrant cultures, including European and African American traditions. In the 20th century, key fashion trends emerged from the countercultural movements of the 1960s and 70s, leading to casual wear, denim jeans, and streetwear becoming central to American fashion.
#                         Today, American clothing emphasizes comfort and individuality, with a heavy influence from pop culture, including sports, music (like hip-hop and rock), and Hollywood. Brands such as Levi’s, Ralph Lauren, and Nike have become globally recognized, reinforcing the country’s influence on global casual wear and sportswear.</p>
#                         <img src="{{site.baseurl}}/images/outfits/map/cowboy.png" alt="USA Casual Clothing">
#                         <img src="{{site.baseurl}}/images/outfits/map/usadress.jpeg" alt="USA Casual Clothing">
#
#                     `;
#                     break;
#                 case 'Japan':
#                     modalHTML = `
#                         <h2>More about Japan's Clothing Style</h2>
#                         <h3>Cultural Influence on Clothing</h3>
#                         <p style="color: #000">Japan's clothing style is a fascinating blend of traditional and contemporary fashion. Traditional garments like the kimono date back over a thousand years, symbolizing Japanese cultural identity. The Edo period (1603–1868) popularized silk kimonos and elaborate designs. After opening to the West in the late 19th century, Japan began incorporating Western-style suits and dresses.
#
# In the 20th century, Japan became a hub for fashion innovation. The Harajuku fashion movement in Tokyo emerged in the 1990s, known for its bold, experimental, and sometimes eccentric styles. Japan's street fashion continues to inspire international designers with its mix of tradition and modernity.
#
# Today, Japanese fashion spans both traditional styles, like kimonos worn for ceremonies, and cutting-edge streetwear, which is popular globally. Japanese designers such as Issey Miyake and Yohji Yamamoto have left a lasting impact on high fashion.</p>
#                         <img src="{{site.baseurl}}/images/outfits/map/kimono.jpeg" alt="Japanese Kimono">
#                         <img src="{{site.baseurl}}/images/outfits/map/tobipants.jpg" alt="Japanese Tobi Pants">
#
#                     `;
#                     break;
#                 case 'China':
#                     modalHTML = `
#                         <h2>More about China's Clothing Style</h2>
#                         <h3>Cultural Influence on Clothing</h3>
#                         <p style="color: #000">China's fashion history is deeply rooted in its imperial past. Traditional Chinese clothing, such as the hanfu during the Han Dynasty and the cheongsam (qipao) in the 20th century, has represented Chinese cultural values and social hierarchy. The cheongsam became popular in Shanghai during the 1920s as a modern take on traditional garments.
#
# After the establishment of the People's Republic of China in 1949, clothing became more practical and less formal. The Mao suit became widespread as a symbol of socialist ideology. However, starting in the late 20th century, China experienced rapid economic growth, and its fashion industry boomed, embracing both traditional styles and Western influences.
#
# Today, Chinese fashion blends the old and new, with modern styles reflecting China’s rich history while adopting global trends. Modern Chinese designers like Guo Pei combine traditional craftsmanship with contemporary design, creating pieces that are celebrated on international runways. </p>
#                         <img src="{{site.baseurl}}/images/outfits/map/chineseclothing.jpg" alt="Chinese Traditional Clothing">
#
#                     `;
#                     break;
#             }
#
#             // Insert content into the modal
#             modalContent.innerHTML = modalHTML;
#             modal.style.display = "block";
#             document.body.classList.add('modal-open');
#         }
#     </script>
# </body>
